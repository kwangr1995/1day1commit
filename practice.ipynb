# %% [markdown]
# Hello world 출력

# %%
print('hello,world!')
# Out:
# hello,world!

# %%
$ git config --global user.email "kwangr1995@gmail.com"
$ git config --global user.name "kwangr1995"
# Out:
#   File "C:\Users\123\AppData\Local\Temp/ipykernel_13672/1003727509.py", line 1
#     $ git config --global user.email "kwangr1995@gmail.com"
#     ^
# SyntaxError: invalid syntax
