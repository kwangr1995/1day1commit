# %%
cd /
# Out:
# C:\

# %%
cd Users
# Out:
# C:\Users

# %%
cd
# Out:
#   File "C:\Users\123\AppData\Local\Temp/ipykernel_39072/1723362444.py", line 3
#     conda create -n gpu_env python = 3.9
#           ^
# SyntaxError: invalid syntax

# %%
conda create -n gpu_env python = 3.9
# Out:
#   File "C:\Users\123\AppData\Local\Temp/ipykernel_39072/2479471726.py", line 1
#     conda create -n gpu_env python = 3.9
#           ^
# SyntaxError: invalid syntax
