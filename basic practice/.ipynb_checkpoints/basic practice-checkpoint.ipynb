# %% [markdown]
# Hello world 출력

# %%
print('hello,world!')
# Out:
# hello,world!

# %%
if 1 + 1 == 2: print('2')
# Out:
# 2

# %% [markdown]
# 인덱싱

# %%
x = [11,12,13,20]
x
# Out:
# [11, 12, 13, 20]

# %%
print(x[0])
print(x[0] * x[3])
# Out:
# 11
# 220

# %% [markdown]
# 딕셔너리

# %%
score = {'korean' : 100, 'math' : 96}
score
# Out:
# {'korean': 100, 'math': 96}

# %%
score['korean']
# Out:
# 100

# %%
ex_dictionary = {1: 35, 2: 13, 'a': 'tommorow'}
ex_dictionary
# Out:
# {1: 35, 2: 13, 'a': 'tommorow'}

# %% [markdown]
# 윤년이 아닌 평년의 경우에 각 달의 날짜 수를 저장하는 변수 days를 만든다. 이 때 각 달을 표시하는 키는 두 글자짜리 문자열로 한다. 즉, 1월은 “01”, 2월은 “02”, 12월은 “12”로 한다.
#
# 변수 days를 이용하여 짝수 달의 평균 날짜 수를 구한다.

# %%
days = {'01': 31, '02': 28, '03': 31,'04': 30, '05': 31, '06': 30,'07': 31, '08': 31, '09': 30,
       '10': 31, '11': 30, '12': 31}

# %%
(days['02'] + days['04'] + days['06'] + days['08'] + days['10'] + days['12'])/6
# Out:
# 30.166666666666668

# %%
#asdasd
